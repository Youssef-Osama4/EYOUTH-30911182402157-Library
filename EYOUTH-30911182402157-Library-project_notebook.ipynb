# %% [markdown]
# # Task 1

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(r'c:\Users\HP\OneDrive\Desktop\download')
print(pd.read_sql_query("SELECT * FROM members", conn))
print(pd.read_sql_query("SELECT * FROM books", conn))
print(pd.read_sql_query("SELECT * FROM checkouts", conn))

print('==========')

query='''
SELECT members.member_id, members.first_name, members.last_name, COUNT(checkouts.member_id) AS checkout_count
FROM members
LEFT JOIN checkouts
ON checkouts.member_id = members.member_id
GROUP BY members.member_id
'''
print(pd.read_sql_query(query, conn)) #How much is each member borrowing?

print('==========')

print(pd.read_sql_query("SELECT title, author FROM books WHERE author LIKE 'H%'", conn)) #Author Patter: name starting with "H"

print('==========')

query = '''
SELECT books.book_id, books.title, COUNT(*) AS borrows_count
FROM checkouts
JOIN books
ON checkouts.book_id = books.book_id
GROUP BY checkouts.book_id
ORDER BY COUNT(*) DESC
LIMIT 5
'''
print(pd.read_sql_query(query, conn)) #What are the most popular books?

print('==========')

query = '''
SELECT members.member_id, members.first_name, COUNT(*) AS borrows_count
FROM checkouts
JOIN members
ON checkouts.member_id = members.member_id
GROUP BY checkouts.member_id
ORDER BY COUNT(*) DESC
LIMIT 10
'''
print(pd.read_sql_query(query, conn)) #Who are the most active readers?

print('==========')

query = '''
SELECT checkouts.checkout_id, members.first_name, checkouts.checkout_date, members.neighborhood
FROM checkouts
JOIN members
ON checkouts.member_id = members.member_id
WHERE members.neighborhood = 'Maadi'
ORDER BY checkouts.checkout_date DESC
LIMIT 10
OFFSET 10
'''
print(pd.read_sql_query(query, conn)) #What does a neighborhood's (Maadi) activity look like further back in time?

print('==========')

df_members = pd.read_sql_query('SELECT * FROM members', conn)
df_books = pd.read_sql_query('SELECT * FROM books', conn)
df_checkouts = pd.read_sql_query('SELECT * FROM checkouts', conn)

stage_1 = pd.merge(df_members, df_checkouts, on='member_id', how='left')
borrows_count = df_checkouts['member_id'].value_counts()
stage_1['book_count'] = stage_1['member_id'].map(borrows_count).fillna(0) #The combined result lets you see for each member how many books they've borrowed in total. 



df_json = pd.read_json(r'c:\Users\HP\OneDrive\Desktop\download (1)')

combined_books = pd.merge(df_books, df_json, on='book_id', how='left') #combining all books information (from json and books sql table)
stage_2 = pd.merge(stage_1, combined_books, on='book_id', how='left')

tables = pd.read_html(r'c:\Users\HP\OneDrive\Desktop\download (2)')
df_html = tables[0]

print("Columns' names:", list(df_html.columns)) #the columns' names are written in a different format from the other dataframe
df_html.columns = ['member_id', 'book_id', 'checkout_date'] #fixing the columns' names

print('==========')

stage_3 = pd.merge(df_html, df_members, on='member_id', how='left') #merging the html with members details to complete its data
stage_3 = pd.merge(stage_3, combined_books, on='book_id', how='left') #merging the html with books details to complete its data
df = pd.concat([stage_2, stage_3], ignore_index=True)

print(df)
df.to_csv('task1_combined_data.csv', index=False)
# Out:
#     member_id first_name last_name  grade neighborhood membership_status  \
# 0        1001      Salma   Ibrahim    8.0        Maadi            Active
# 1        1002      Fares     Saleh    9.0        Maadi            Active
# 2        1003     Bassel    Hegazy    6.0        Maadi            Active
# 3        1004      Fares     Wahba    7.0        Maadi          inactive
# 4        1005    Youssef     Halim    9.0        Maadi            Active
# ..        ...        ...       ...    ...          ...               ...
# 75       1076       Dina     Wahba    7.0       Shubra            Active
# 76       1077       Lina    Rashad    6.0       Shubra            Active
# 77       1078     Habiba     Osman    7.0       Shubra          INACTIVE
# 78       1079       Rana     Osman    8.0       Shubra            Active
# 79       1080     Bassel     Wahba    9.0       Shubra            Active
#
#      join_date
# 0   2023-04-05
# 1         None
# 2   2025-04-23
# 3   2024-10-09
# 4   2024-05-05
# ..         ...
# 75  2025-12-13
# 76  2023-07-08
# 77  2023-08-05
# 78  2024-10-27
# 79  2023-12-28
#
# [80 rows x 7 columns]
#     book_id                    title          author
# 0       501          The Silver Kite   Amina Darwish
# 1       502           Desert Compass   Amina Darwish
# 2       503        The Lantern Maker    Adel Roushdy
# 3       504      Rooftop Astronomers    Adel Roushdy
# 4       505      Letters to the Nile       Aya Hafez
# 5       506      The Paper Boat Club       Aya Hafez
# 6       507    Fossils and Fireflies     Dalia Serry
# 7       508    The Quiet Observatory     Dalia Serry
# 8       509      Marbles and Mirrors     Diaa Sultan
# 9       510    The Missing Metronome     Diaa Sultan
# 10      511     Winter in Alexandria    Farida Anwar
# 11      512   The Cartographer's Cat    Farida Anwar
# 12      513   Circuits for Beginners    Galal Mounir
# 13      514    The Robot in Row Nine    Galal Mounir
# 14      515       Songs of the Oasis      Hoda Bakry
# 15      516  The Beekeeper's Almanac      Hoda Bakry
# 16      517  Shadows on the Corniche     Hani Nagati
# 17      518     The Ninth Lighthouse     Hani Nagati
# 18      519         Kites Over Cairo  Jasmine Wahdan
# 19      520     The Copper Telescope  Jasmine Wahdan
# 20      521    A Garden of Equations      Karim Elwy
# 21      522      The Puzzle Merchant      Karim Elwy
# 22      523    Footsteps in the Dust    Laila Shokry
# 23      524    The Weaver's Daughter    Laila Shokry
# 24      525     Storms and Sailboats   Mahmoud Rafei
# 25      526    The Clockwork Orchard   Mahmoud Rafei
# 26      527     Notes from the Delta  Mona Kholoussy
# 27      528        The Glass Beehive  Mona Kholoussy
# 28      529   Riddles of the Red Sea    Sara Tantawy
# 29      530        The Sandstone Key    Sara Tantawy
# 30      531    Voices in the Library     Samir Zohdy
# 31      532        The Last Bookmark     Samir Zohdy
#      checkout_id  member_id  book_id checkout_date return_date
# 0           9263       1047      517    2024-10-21  2024-11-07
# 1           9340       1072      513    2025-08-24  2025-09-01
# 2           9231       1053      523    2024-02-04  2024-02-16
# 3           9129       1032      513    2025-06-21  2025-06-29
# 4           9370       1079      511    2025-11-11  2025-12-03
# ..           ...        ...      ...           ...         ...
# 386         9232       1044      513    2025-05-26  2025-06-11
# 387         9084       1008      511    2024-06-27  2024-07-22
# 388         9116       1024      519    2025-01-10  2025-02-09
# 389         9352       1076      501    2025-02-02        None
# 390         9246       1044      529    2025-06-25  2025-07-04
#
# [391 rows x 5 columns]
# ==========
#     member_id first_name last_name  checkout_count
# 0        1001      Salma   Ibrahim               1
# 1        1002      Fares     Saleh               2
# 2        1003     Bassel    Hegazy               9
# 3        1004      Fares     Wahba               0
# 4        1005    Youssef     Halim               3
# ..        ...        ...       ...             ...
# 75       1076       Dina     Wahba               7
# 76       1077       Lina    Rashad               6
# 77       1078     Habiba     Osman               0
# 78       1079       Rana     Osman              10
# 79       1080     Bassel     Wahba               2
#
# [80 rows x 4 columns]
# ==========
#                      title       author
# 0       Songs of the Oasis   Hoda Bakry
# 1  The Beekeeper's Almanac   Hoda Bakry
# 2  Shadows on the Corniche  Hani Nagati
# 3     The Ninth Lighthouse  Hani Nagati
# ==========
#    book_id                   title  borrows_count
# 0      501         The Silver Kite             57
# 1      507   Fossils and Fireflies             55
# 2      513  Circuits for Beginners             46
# 3      519        Kites Over Cairo             38
# 4      525    Storms and Sailboats             25
# ==========
#    member_id first_name  borrows_count
# 0       1034        Aya             25
# 1       1044     Sherif             21
# 2       1008       Ziad             19
# 3       1027    Mostafa             18
# 4       1010       Nour             18
# 5       1065       Adam             17
# 6       1024    Youssef             17
# 7       1018      Ahmed             17
# 8       1047       Sara             16
# 9       1030       Reem             16
# ==========
#    checkout_id first_name checkout_date neighborhood
# 0         9103     Bassel    2025-09-04        Maadi
# 1         9081       Adam    2025-08-25        Maadi
# 2         9001       Ziad    2025-08-23        Maadi
# 3         9050     Bassel    2025-08-21        Maadi
# 4         9085      Ahmed    2025-08-19        Maadi
# 5         9055      Hamza    2025-08-08        Maadi
# 6         9023      Ahmed    2025-08-04        Maadi
# 7         9004       Ziad    2025-07-27        Maadi
# 8         9051     Bassel    2025-07-22        Maadi
# 9         9010     Hassan    2025-07-22        Maadi
# ==========
# Columns' names: ['Member ID', 'Book ID', 'Checkout Date']
# ==========
#      member_id first_name last_name  grade neighborhood membership_status  \
# 0         1001      Salma   Ibrahim    8.0        Maadi            Active
# 1         1002      Fares     Saleh    9.0        Maadi            Active
# 2         1002      Fares     Saleh    9.0        Maadi            Active
# 3         1003     Bassel    Hegazy    6.0        Maadi            Active
# 4         1003     Bassel    Hegazy    6.0        Maadi            Active
# ..         ...        ...       ...    ...          ...               ...
# 430       1003     Bassel    Hegazy    6.0        Maadi            Active
# 431       1017       Adam      Badr    9.0        Maadi            Active
# 432       1061       Ziad     Fahmy    9.0      zamalek          Inactive
# 433       1201        NaN       NaN    NaN          NaN               NaN
# 434       1041       Nada    Rashad    7.0    Nasr City            Active
#
#       join_date  checkout_id  book_id checkout_date return_date  book_count  \
# 0    2023-04-05       9025.0    525.0    2024-10-24  2024-11-07         1.0
# 1          None       9013.0    501.0    2024-02-16  2024-02-29         2.0
# 2          None       9095.0    507.0    2024-06-25  2024-07-07         2.0
# 3    2025-04-23       9051.0    513.0    2025-07-22  2025-08-18         9.0
# 4    2025-04-23       9068.0    501.0    2025-11-14  2025-12-03         9.0
# ..          ...          ...      ...           ...         ...         ...
# 430  2025-04-23          NaN    501.0    2025-07-08         NaN         NaN
# 431  2025-07-12          NaN    507.0    2025-07-11         NaN         NaN
# 432  2023-04-27          NaN    504.0    2025-07-06         NaN         NaN
# 433         NaN          NaN    523.0    2025-07-08         NaN         NaN
# 434  2024-04-02          NaN    512.0    2025-07-06         NaN         NaN
#
#                       title         author       genre  pages  \
# 0      Storms and Sailboats  Mahmoud Rafei   Adventure  297.0
# 1           The Silver Kite  Amina Darwish   Adventure  128.0
# 2     Fossils and Fireflies    Dalia Serry     Science  160.0
# 3    Circuits for Beginners   Galal Mounir     Science  294.0
# 4           The Silver Kite  Amina Darwish   Adventure  128.0
# ..                      ...            ...         ...    ...
# 430         The Silver Kite  Amina Darwish   Adventure  128.0
# 431   Fossils and Fireflies    Dalia Serry     Science  160.0
# 432     Rooftop Astronomers   Adel Roushdy     Science  319.0
# 433   Footsteps in the Dust   Laila Shokry  Historical  276.0
# 434  The Cartographer's Cat   Farida Anwar   Adventure  238.0
#
#      publication_year            publisher
# 0              2015.0          Oasis Books
# 1              2017.0           Nile Press
# 2              2024.0           Nile Press
# 3              2021.0          Oasis Books
# 4              2017.0           Nile Press
# ..                ...                  ...
# 430            2017.0           Nile Press
# 431            2024.0           Nile Press
# 432            2009.0  Cairo Young Readers
# 433            2018.0          Oasis Books
# 434            2022.0          Delta House
#
# [435 rows x 18 columns]

# %% [markdown]
# # Task 2

# %%
import pandas as pd

df = pd.read_csv('task1_combined_data.csv')
print(df.head())

print('==========')

# print('Missing values to number of rows ratio in percentage per column:')
# print(df.isna().sum() / len(df) * 100) #checking the missing values to total number of rows ratio in percentage per column

print('==========')

print(f"Duplicate rows (checkout_id): {df.duplicated(subset=['checkout_id']).sum()}") #There are a lot of nans in the checkout_id column which are considered duplicates, so we will check for duplicates in all columns.
print(f"Duplicate rows (all columns): {df.duplicated().sum()}") 
print(f"Missing values in checkout_id): {df['checkout_id'].isna().sum()}") #checking the missing values in the checkout_id column to make sure all the extra duplicates are due to the nans in this column

df = df.drop_duplicates() #dropping the duplicates

print('==========')

string_columns = ['first_name', 'last_name', 'neighborhood', 'membership_status', 'title', 'author', 'genre', 'publisher']
for column in string_columns:
    df[column] = df[column].str.strip().str.title()
    print(f"- Unique values in {column}: {df[column].unique()}") #No more consistency issues in the string columns

print(df.dtypes) #checking the datatypes of the columns, dates aren't datetime, and membership_status is object instead of category

df['membership_status'] = df['membership_status'].astype('category')

dates = ['checkout_date', 'return_date', 'join_date']
for column in dates:
    df[column] = pd.to_datetime(df[column], format='mixed') #converting the date columns to datetime format, errors='coerce' will convert any invalid date to NaT

print(df.describe()) #checking for problems in the numerical columns, No problems found

print('==========')

unregistered_members = df[~df['member_id'].isin(df_members['member_id'])]
print(unregistered_members)

df = df[df['member_id'].isin(df_members['member_id'])] #removing the invalid members from the dataframe


df.to_csv('task2_cleaned_data.csv', index=False)
# Out:
#    member_id first_name last_name  grade neighborhood membership_status  \
# 0       1001      Salma   Ibrahim    8.0        Maadi            Active
# 1       1002      Fares     Saleh    9.0        Maadi            Active
# 2       1002      Fares     Saleh    9.0        Maadi            Active
# 3       1003     Bassel    Hegazy    6.0        Maadi            Active
# 4       1003     Bassel    Hegazy    6.0        Maadi            Active
#
#     join_date  checkout_id  book_id checkout_date return_date  book_count  \
# 0  2023-04-05       9025.0    525.0    2024-10-24  2024-11-07         1.0
# 1         NaN       9013.0    501.0    2024-02-16  2024-02-29         2.0
# 2         NaN       9095.0    507.0    2024-06-25  2024-07-07         2.0
# 3  2025-04-23       9051.0    513.0    2025-07-22  2025-08-18         9.0
# 4  2025-04-23       9068.0    501.0    2025-11-14  2025-12-03         9.0
#
#                     title         author      genre  pages  publication_year  \
# 0    Storms and Sailboats  Mahmoud Rafei  Adventure  297.0            2015.0
# 1         The Silver Kite  Amina Darwish  Adventure  128.0            2017.0
# 2   Fossils and Fireflies    Dalia Serry    Science  160.0            2024.0
# 3  Circuits for Beginners   Galal Mounir    Science  294.0            2021.0
# 4         The Silver Kite  Amina Darwish  Adventure  128.0            2017.0
#
#      publisher
# 0  Oasis Books
# 1   Nile Press
# 2   Nile Press
# 3  Oasis Books
# 4   Nile Press
# ==========
# ==========
# Duplicate rows (checkout_id): 51
# Duplicate rows (all columns): 8
# Missing values in checkout_id): 44
# ==========
# - Unique values in first_name: ['Salma' 'Fares' 'Bassel' 'Youssef' 'Layla' 'Sherif' 'Ziad' 'Hassan'
#  'Nour' 'Menna' 'Ali' 'Habiba' 'Hamza' 'Dina' 'Adam' 'Ahmed' 'Mostafa'
#  'Rana' 'Hana' 'Nada' 'Reem' 'Marwan' 'Aya' 'Karim' 'Lina' 'Retaj' 'Mai'
#  'Amir' 'Sara' 'Farida' 'Tarek' 'Jana' 'Seif' 'Yassin' 'Malak' nan]
# - Unique values in last_name: ['Ibrahim' 'Saleh' 'Hegazy' 'Wahba' 'Halim' 'Mansour' 'Fouad' 'Nabil'
#  'Sabry' 'Rashad' 'Badr' 'Shafik' 'Adel' 'Kamel' 'Osman' 'Fahmy' 'Zaki'
#  'Riad' 'Gamal' nan]
# - Unique values in neighborhood: ['Maadi' 'Nasr City' 'Nasr  City' 'Heliopolis' 'Zamalek' 'Shubra' nan]
# - Unique values in membership_status: ['Active' 'Inactive' nan]
# - Unique values in title: ['Storms And Sailboats' 'The Silver Kite' 'Fossils And Fireflies'
#  'Circuits For Beginners' 'The Lantern Maker' 'A Garden Of Equations'
#  'Kites Over Cairo' 'The Puzzle Merchant' nan 'Letters To The Nile'
#  'The Paper Boat Club' "The Beekeeper'S Almanac" 'Desert Compass'
#  'The Robot In Row Nine' 'Marbles And Mirrors' 'Riddles Of The Red Sea'
#  'The Copper Telescope' 'Winter In Alexandria' 'The Glass Beehive'
#  'Songs Of The Oasis' 'Notes From The Delta' 'The Missing Metronome'
#  'The Ninth Lighthouse' 'The Sandstone Key' 'The Last Bookmark'
#  "The Weaver'S Daughter" 'Shadows On The Corniche'
#  "The Cartographer'S Cat" 'The Clockwork Orchard' 'Voices In The Library'
#  'Footsteps In The Dust' 'The Quiet Observatory' 'Rooftop Astronomers']
# - Unique values in author: ['Mahmoud Rafei' 'Amina Darwish' 'Dalia Serry' 'Galal Mounir'
#  'Adel Roushdy' 'Karim Elwy' 'Jasmine Wahdan' nan 'Aya Hafez' 'Hoda Bakry'
#  'Diaa Sultan' 'Sara Tantawy' 'Farida Anwar' 'Mona Kholoussy'
#  'Hani Nagati' 'Samir Zohdy' 'Laila Shokry']
# - Unique values in genre: ['Adventure' 'Science' 'Historical' 'Friendship' 'Mystery' nan 'Nature'
#  'Science Fiction' 'Poetry']
# - Unique values in publisher: ['Oasis Books' 'Nile Press' 'Cairo Young Readers' nan 'Delta House']
# member_id              int64
# first_name            object
# last_name             object
# grade                float64
# neighborhood          object
# membership_status     object
# join_date             object
# checkout_id          float64
# book_id              float64
# checkout_date         object
# return_date           object
# book_count           float64
# title                 object
# author                object
# genre                 object
# pages                float64
# publication_year     float64
# publisher             object
# dtype: object
#          member_id       grade                      join_date  checkout_id  \
# count   427.000000  384.000000                            415    383.00000
# mean   1041.093677    7.554688  2024-08-29 13:52:46.265060352   9192.00000
# min    1001.000000    6.000000            2023-01-19 00:00:00   9001.00000
# 25%    1020.000000    7.000000            2024-01-04 00:00:00   9096.50000
# 50%    1038.000000    8.000000            2024-09-27 00:00:00   9192.00000
# 75%    1061.000000    9.000000            2025-07-12 00:00:00   9287.50000
# max    1201.000000    9.000000            2025-12-26 00:00:00   9383.00000
# std      26.272956    1.152647                            NaN    110.70682
#
#           book_id                  checkout_date  \
# count  409.000000                            409
# mean   513.422983  2025-02-03 14:50:45.476772352
# min    501.000000            2024-01-02 00:00:00
# 25%    507.000000            2024-08-20 00:00:00
# 50%    513.000000            2025-02-26 00:00:00
# 75%    519.000000            2025-07-10 00:00:00
# max    532.000000            2025-12-28 00:00:00
# std      8.943974                            NaN
#
#                          return_date  book_count       pages  publication_year
# count                            318  401.000000  409.000000        376.000000
# mean   2025-02-22 05:53:12.452830208   11.630923  201.853301       2017.417553
# min              2024-01-22 00:00:00    0.000000  104.000000       2009.000000
# 25%              2024-09-14 06:00:00    6.000000  134.000000       2014.000000
# 50%              2025-03-14 12:00:00   11.000000  160.000000       2017.000000
# 75%              2025-08-04 12:00:00   17.000000  294.000000       2021.000000
# max              2026-01-15 00:00:00   25.000000  338.000000       2024.000000
# std                              NaN    7.214807   73.716056          4.582123
# ==========
#      member_id first_name last_name  grade neighborhood membership_status  \
# 413       1104        NaN       NaN    NaN          NaN               NaN
# 418       1201        NaN       NaN    NaN          NaN               NaN
# 420       1104        NaN       NaN    NaN          NaN               NaN
# 423       1150        NaN       NaN    NaN          NaN               NaN
# 433       1201        NaN       NaN    NaN          NaN               NaN
#
#     join_date  checkout_id  book_id checkout_date return_date  book_count  \
# 413       NaT          NaN    515.0    2025-07-07         NaT         NaN
# 418       NaT          NaN    509.0    2025-07-10         NaT         NaN
# 420       NaT          NaN    526.0    2025-07-05         NaT         NaN
# 423       NaT          NaN    530.0    2025-07-10         NaT         NaN
# 433       NaT          NaN    523.0    2025-07-08         NaT         NaN
#
#                      title         author            genre  pages  \
# 413     Songs Of The Oasis     Hoda Bakry           Poetry  316.0
# 418    Marbles And Mirrors    Diaa Sultan          Mystery  221.0
# 420  The Clockwork Orchard  Mahmoud Rafei  Science Fiction  125.0
# 423      The Sandstone Key   Sara Tantawy        Adventure  208.0
# 433  Footsteps In The Dust   Laila Shokry       Historical  276.0
#
#      publication_year            publisher
# 413            2022.0  Cairo Young Readers
# 418            2011.0           Nile Press
# 420            2016.0          Delta House
# 423            2012.0          Oasis Books
# 433            2018.0          Oasis Books
